# %% [markdown]
# # Quiz Pekan - 3
#
# Dataset-dataset berikut ini menunjukkan persentase fat, protein, dan food yang dikonsumsi dari setiap jenis makanan yang terdaftar. Beberapa bagian akhir dataset juga mencakup persentase obesitas(Obesity), kurang gizi(Undernourished), dan kasus COVID-19 yang Terkonfirmasi(Confirmed)/Kematian(Deaths)/Sembuh(Recovered)/Aktif(Active).
#
# (Catatan: Semua data memiliki unit '%' (persen) kecuali Populasi, unit persen tersebut dihitung berdasarkan jumlah populasi).
#
# Link Download:
#
# [Food_Supply_Quantity_kg_Data.csv](https://drive.google.com/uc?export=download&id=1kBTLQViyAGzrvuTCxdBHeUXJAgAlVJgu)
#
# [Protein_Supply_Quantity_Data.csv](https://drive.google.com/uc?export=download&id=1Y7CfCRxQpfeqsnwMYV93CkuS2IQgN1tJ)
#
# [Fat_Supply_Quantity_Data.csv](https://drive.google.com/uc?export=download&id=1Uwiq7iID86wHysLFHvWr2cpSAQC22sc4)
#
# [Supply_Food_Data_Descriptions.csv](https://drive.google.com/uc?export=download&id=1eM6yE6yzujnczNbDhHrcUqrhiiohBh2x)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import Semua Data
df_food = pd.read_csv('dataset/Food_Supply_Quantity_kg_Data.csv')
df_protein = pd.read_csv('dataset/Protein_Supply_Quantity_Data.csv')
df_fat = pd.read_csv('dataset/Fat_Supply_Quantity_Data.csv')
df_category = pd.read_csv('dataset/Supply_Food_Data_Descriptions.csv')

# %%
df_food
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 0             9.4341                   0.0000                   24.8097
# 1            18.7684                   0.0000                    5.7817
# 2             9.6334                   0.0000                   13.6816
# 3             4.9278                   0.0000                    9.1085
# 4            16.6613                   0.0000                    5.9960
# ..               ...                      ...                       ...
# 165          14.7565                   0.0000                   12.9253
# 166           8.5765                   0.0042                   16.8740
# 167           5.7874                   0.0000                   27.2077
# 168           6.0197                   0.0000                   21.1938
# 169           8.1489                   0.0000                   22.6240
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  ...  Vegetables  \
# 0    0.2099         0.0350                   5.3495  1.2020  ...      6.7642
# 1    0.5815         0.2126                   6.7861  1.8845  ...     11.7753
# 2    0.5277         0.2416                   6.3801  1.1305  ...     11.6484
# 3    0.0587         1.7707                   6.0005  2.0571  ...      2.3041
# 4    0.2274         4.1489                  10.7451  5.6888  ...      5.4495
# ..      ...            ...                      ...     ...  ...         ...
# 165  0.3389         0.9456                   7.6460  3.8328  ...      4.1474
# 166  0.3077         2.6392                   5.9029  4.4382  ...     11.9508
# 167  0.2579         0.5240                   5.1344  2.7871  ...      3.2135
# 168  0.3399         1.6924                   1.0183  1.8427  ...      3.4649
# 169  0.2678         0.5518                   2.2000  2.6142  ...      2.3213
#
#      Vegetal Products  Obesity  Undernourished  Confirmed    Deaths  \
# 0             40.5645      4.5            29.8   0.130125  0.005461
# 1             31.2304     22.3             6.2   1.931889  0.039641
# 2             40.3651     26.6             3.9   0.218696  0.006098
# 3             45.0722      6.8              25   0.052361  0.001208
# 4             33.3233     19.1             NaN   0.157143  0.005102
# ..                ...      ...             ...        ...       ...
# 165           35.2416     25.2            21.2   0.388357  0.003512
# 166           41.4232      2.1             9.3   0.001488  0.000036
# 167           44.2126     14.1            38.9   0.007014  0.002032
# 168           43.9789      6.5            46.7   0.104624  0.002072
# 169           41.8526     12.3            51.3   0.086026  0.002281
#
#      Recovered    Active  Population  Unit (all except Population)
# 0     0.103676  0.020987  38928000.0                             %
# 1     1.066808  0.825440   2838000.0                             %
# 2     0.146036  0.066562  44357000.0                             %
# 3     0.029915  0.021238  32522000.0                             %
# 4     0.148980  0.003061     98000.0                             %
# ..         ...       ...         ...                           ...
# 165   0.368228  0.016617  28645000.0                             %
# 166   0.001331  0.000121  96209000.0                             %
# 167   0.004640  0.000342  29826000.0                             %
# 168   0.098107  0.004444  18384000.0                             %
# 169   0.069394  0.014351  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
df_protein
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 0         0.0277                   0.0000                   35.9771  0.4067
# 1         0.0711                   0.0000                   14.2331  1.8069
# 2         0.0054                   0.0000                   26.5633  1.2916
# 3         0.0277                   0.0000                   20.3882  0.1756
# 4         0.1289                   0.0000                   10.5108  0.4850
# ..           ...                      ...                       ...     ...
# 165       0.1244                   0.0000                   21.6526  0.8707
# 166       0.1555                   0.0056                   18.5247  0.7665
# 167       0.0188                   0.0000                   35.1179  0.4320
# 168       0.0338                   0.0000                   28.5182  0.5839
# 169       0.0391                   0.0000                   33.1934  0.5077
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetables  \
# 0           0.0647                   0.5824   3.1337  ...      1.1370
# 1           0.6274                   1.2757   7.6582  ...      3.2456
# 2           0.6350                   1.1624   3.5088  ...      3.1267
# 3           5.4436                   1.2754   7.6248  ...      0.8133
# 4           8.2146                   1.2586  16.0670  ...      1.6024
# ..             ...                      ...      ...  ...         ...
# 165         2.6477                   1.0662  11.8347  ...      1.0129
# 166         5.7435                   0.7165  11.0426  ...      3.7216
# 167         0.9392                   0.4884   5.9453  ...      0.5448
# 168         3.0126                   0.0931   4.3158  ...      0.8039
# 169         1.0837                   0.2636   6.6582  ...      0.5955
#
#      Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0           0.0462      4.5            29.8   0.130125  0.005461   0.103676
# 1           0.0544     22.3             6.2   1.931889  0.039641   1.066808
# 2           0.1399     26.6             3.9   0.218696  0.006098   0.146036
# 3           0.0924      6.8              25   0.052361  0.001208   0.029915
# 4           0.2947     19.1             NaN   0.157143  0.005102   0.148980
# ..             ...      ...             ...        ...       ...        ...
# 165         0.0267     25.2            21.2   0.388357  0.003512   0.368228
# 166         0.0389      2.1             9.3   0.001488  0.000036   0.001331
# 167         0.0564     14.1            38.9   0.007014  0.002032   0.004640
# 168         0.0592      6.5            46.7   0.104624  0.002072   0.098107
# 169         0.0586     12.3            51.3   0.086026  0.002281   0.069394
#
#        Active  Population  Unit (all except Population)
# 0    0.020987  38928000.0                             %
# 1    0.825440   2838000.0                             %
# 2    0.066562  44357000.0                             %
# 3    0.021238  32522000.0                             %
# 4    0.003061     98000.0                             %
# ..        ...         ...                           ...
# 165  0.016617  28645000.0                             %
# 166  0.000121  96209000.0                             %
# 167  0.000342  29826000.0                             %
# 168  0.004444  18384000.0                             %
# 169  0.014351  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
df_fat
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 0         6.2224                      0.0                    8.0353  0.6859
# 1         3.4172                      0.0                    2.6734  1.6448
# 2         0.8972                      0.0                    4.2035  1.2171
# 3         1.3130                      0.0                    6.5545  0.1539
# 4         4.6686                      0.0                    3.2153  0.3872
# ..           ...                      ...                       ...     ...
# 165       2.2673                      0.0                    2.5449  0.6555
# 166       3.8238                      0.0                    3.7155  0.7839
# 167       2.0131                      0.0                   11.5271  0.5514
# 168       1.6113                      0.0                   14.3225  0.6266
# 169       2.9543                      0.0                    9.7922  0.3682
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetable Oils  \
# 0           0.0327                   0.4246   6.1244  ...         17.0831
# 1           0.1445                   0.6418   8.7428  ...          9.2443
# 2           0.2008                   0.5772   3.8961  ...         27.3606
# 3           1.4155                   0.3488  11.0268  ...         22.4638
# 4           1.5263                   1.2177  14.3202  ...         14.4436
# ..             ...                      ...      ...  ...             ...
# 165         0.5707                   0.9640   7.0949  ...         29.5211
# 166         1.1217                   0.4079  26.4292  ...          5.6211
# 167         0.3847                   0.2564   8.0010  ...         23.6312
# 168         1.0070                   0.1343   4.9010  ...         15.2848
# 169         0.2455                   0.0614   4.5674  ...         26.9396
#
#      Vegetables  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0        0.3593      4.5            29.8   0.130125  0.005461   0.103676
# 1        0.6503     22.3             6.2   1.931889  0.039641   1.066808
# 2        0.5145     26.6             3.9   0.218696  0.006098   0.146036
# 3        0.1231      6.8              25   0.052361  0.001208   0.029915
# 4        0.2469     19.1             NaN   0.157143  0.005102   0.148980
# ..          ...      ...             ...        ...       ...        ...
# 165      0.1851     25.2            21.2   0.388357  0.003512   0.368228
# 166      0.6373      2.1             9.3   0.001488  0.000036   0.001331
# 167      0.1667     14.1            38.9   0.007014  0.002032   0.004640
# 168      0.1567      6.5            46.7   0.104624  0.002072   0.098107
# 169      0.0789     12.3            51.3   0.086026  0.002281   0.069394
#
#        Active  Population  Unit (all except Population)
# 0    0.020987  38928000.0                             %
# 1    0.825440   2838000.0                             %
# 2    0.066562  44357000.0                             %
# 3    0.021238  32522000.0                             %
# 4    0.003061     98000.0                             %
# ..        ...         ...                           ...
# 165  0.016617  28645000.0                             %
# 166  0.000121  96209000.0                             %
# 167  0.000342  29826000.0                             %
# 168  0.004444  18384000.0                             %
# 169  0.014351  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
df_category
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# 3   Aquatic Animals, Others; Aquatic Plants; Meat,...
# 4   Barley and products; Cereals, Other; Maize and...
# 5                                                Eggs
# 6   Cephalopods; Crustaceans; Demersal Fish; Fresh...
# 7   Apples and products; Bananas; Citrus, Other; D...
# 8   Bovine Meat; Meat, Other; Mutton & Goat Meat; ...
# 9                             Milk - Excluding Butter
# 10                         Infant food; Miscellaneous
# 11                                     Offals, Edible
# 12  Coconuts - Incl Copra; Cottonseed; Groundnuts ...
# 13            Beans; Peas; Pulses, Other and products
# 14             Cloves; Pepper; Pimento; Spices, Other
# 15  Cassava and products; Potatoes and products; R...
# 16  Cocoa Beans and products; Coffee and products;...
# 17  Honey; Sugar (Raw Equivalent); Sugar non-centr...
# 18                             Sugar beet; Sugar cane
# 19                                  Nuts and products
# 20  Coconut Oil; Cottonseed Oil; Groundnut Oil; Ma...
# 21   Onions; Tomatoes and products; Vegetables, Other
# 22  Alcohol, Non-Food; Apples and products; Banana...

# %% [markdown]
# ---

# %% [markdown]
# # Soal 1 : Apakah harapan kalian saat mengikuti kelas Python Datascience dasar? (poin:5)

# %% [markdown]
# Bisa mengetahui dan mengaplikasikan data science dalam kuliah dan dalam pekerjaan

# %% [markdown]
# # Soal 2: Memisahkan kolom pada supply dataset antara kategori makanan dan bukan makanan

# %% [markdown]
# Teman-teman diminta untuk menampilkan list kolom-kolom pada supply DataFrame dengan ketentuan sebagai berikut:
#
# *   all columns: list yang berisikan semua kolom pada supply DataFrame
# *   supply columns: list yang berisikan semua kolom pada supply DataFrame berdasarkan kolom 'Categories' pada DataFrame df_category
# *   non-supply columns: list yang berisikan semua kolom non-supply pada supply DataFrame

# %%
# Code here
allcol = df_food.columns.tolist()
print('All Columns : {}'.format(allcol))
print()
# Out:
# All Columns : ['Country', 'Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %%
df_category.pop('Items')
# Out:
# 0     Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1     Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2     Aquatic Animals, Others; Aquatic Plants; Bovin...
# 3     Aquatic Animals, Others; Aquatic Plants; Meat,...
# 4     Barley and products; Cereals, Other; Maize and...
# 5                                                  Eggs
# 6     Cephalopods; Crustaceans; Demersal Fish; Fresh...
# 7     Apples and products; Bananas; Citrus, Other; D...
# 8     Bovine Meat; Meat, Other; Mutton & Goat Meat; ...
# 9                               Milk - Excluding Butter
# 10                           Infant food; Miscellaneous
# 11                                       Offals, Edible
# 12    Coconuts - Incl Copra; Cottonseed; Groundnuts ...
# 13              Beans; Peas; Pulses, Other and products
# 14               Cloves; Pepper; Pimento; Spices, Other
# 15    Cassava and products; Potatoes and products; R...
# 16    Cocoa Beans and products; Coffee and products;...
# 17    Honey; Sugar (Raw Equivalent); Sugar non-centr...
# 18                               Sugar beet; Sugar cane
# 19                                    Nuts and products
# 20    Coconut Oil; Cottonseed Oil; Groundnut Oil; Ma...
# 21     Onions; Tomatoes and products; Vegetables, Other
# 22    Alcohol, Non-Food; Apples and products; Banana...
# Name: Items, dtype: object

# %%
ud = df_category['Categories'].tolist()
print(ud)
# Out:
# ['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products']

# %%
din = df_food.columns.tolist()
print(din)
# Out:
# ['Country', 'Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %%
c = [x for x in din if x in ud]
print('Supply Columns : {}'.format(c))
# Out:
# Supply Columns : ['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products']

# %%
d = [y for y in din if y not in ud]
print('Non Supply Columns : {}'.format(d))
# Out:
# Non Supply Columns : ['Country', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %% [markdown]
# Expected Output:
#
# ![Expected Output:](https://drive.google.com/uc?id=1L6exgfQO0VSjyhxuF4cDwvNdvPQf0xLo)

# %% [markdown]
# ---

# %% [markdown]
# # Soal 3: Menggabungkan DataFrame

# %% [markdown]
# Gabungkan semua supply DataFrame dengan ketentuan tidak ada kolom dengan nama yang sama. Untuk kolom-kolom non-supply seperti tersebut di atas, memiliki nilai yang sama untuk setiap DataFrame, sehingga cukup ambil dari salah satu DataFrame. Sedangkan untuk kolom-kolom supply seperti tersebut di atas, setiap DataFrame (df_food, df_protein, df_fat) memiliki nilai yang berbeda, sehingga teman-teman perlu menambahkan suffix berdasarkan jenis supply DataFrame-nya, misalkan untuk kolom 'eggs' teman teman harus menambahkan suffix sehingga DataFrame gabungan memiliki kolom 'eggs_food', 'eggs_protein', dan 'eggs_fat'. Untuk mendapatkan gambaran lebih jelas, silahkan lihat pada expected output.

# %% [markdown]
# List kolom-kolom DataFrame hasil gabungan adalah sebagai berikut:
#
#
# ```
#  ['Country', 'Alcoholic Beverages_food', 'Animal fats_food',
#   'Animal Products_food', 'Aquatic Products, Other_food',
#   'Cereals - Excluding Beer_food', 'Eggs_food', 'Fish, Seafood_food',
#   'Fruits - Excluding Wine_food', 'Meat_food',
#   'Milk - Excluding Butter_food', 'Miscellaneous_food', 'Offals_food',
#   'Oilcrops_food', 'Pulses_food', 'Spices_food', 'Starchy Roots_food',
#   'Stimulants_food', 'Sugar & Sweeteners_food', 'Sugar Crops_food',
#   'Treenuts_food', 'Vegetable Oils_food', 'Vegetables_food',
#   'Vegetal Products_food', 'Alcoholic Beverages_protein',
#   'Animal fats_protein', 'Animal Products_protein',
#   'Aquatic Products, Other_protein', 'Cereals - Excluding Beer_protein',
#   'Eggs_protein', 'Fish, Seafood_protein',
#   'Fruits - Excluding Wine_protein', 'Meat_protein',
#   'Milk - Excluding Butter_protein', 'Miscellaneous_protein',
#   'Offals_protein', 'Oilcrops_protein', 'Pulses_protein',
#   'Spices_protein', 'Starchy Roots_protein', 'Stimulants_protein',
#   'Sugar & Sweeteners_protein', 'Sugar Crops_protein', 'Treenuts_protein',
#   'Vegetable Oils_protein', 'Vegetables_protein',
#   'Vegetal Products_protein', 'Alcoholic Beverages_fat',
#   'Animal fats_fat', 'Animal Products_fat', 'Aquatic Products, Other_fat',
#   'Cereals - Excluding Beer_fat', 'Eggs_fat', 'Fish, Seafood_fat',
#   'Fruits - Excluding Wine_fat', 'Meat_fat',
#   'Milk - Excluding Butter_fat', 'Miscellaneous_fat', 'Offals_fat',
#   'Oilcrops_fat', 'Pulses_fat', 'Spices_fat', 'Starchy Roots_fat',
#   'Stimulants_fat', 'Sugar & Sweeteners_fat', 'Sugar Crops_fat',
#   'Treenuts_fat', 'Vegetable Oils_fat', 'Vegetables_fat',
#   'Vegetal Products_fat', 'Obesity', 'Undernourished', 'Confirmed',
#   'Deaths', 'Recovered', 'Active', 'Population',
#   'Unit (all except Population)']
# ```

# %%
# Hint
df_non_supply_new = df_food[non_supply_columns]
df_food_new = df_food[['Country']+supply_columns]
df_protein_new = df_protein[['Country']+supply_columns]
df_fat_new = df_fat[['Country']+supply_columns]

# %%
df_non_supply_new = df_food[d]
df_food_new = df_food[['Country']+c]
df_protein_new = df_protein[['Country']+c]
df_fat_new = df_fat[['Country']+c]

# %%
df_fat_new
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0000       6.2224
# 1                               Albania               0.0000       3.4172
# 2                               Algeria               0.0000       0.8972
# 3                                Angola               0.0000       1.3130
# 4                   Antigua and Barbuda               0.0000       4.6686
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               0.0000       2.2673
# 166                             Vietnam               0.0000       3.8238
# 167                               Yemen               0.0000       2.0131
# 168                              Zambia               0.0783       1.6113
# 169                            Zimbabwe               0.0000       2.9543
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 0            21.6397                      0.0                    8.0353
# 1            32.0002                      0.0                    2.6734
# 2            14.4175                      0.0                    4.2035
# 3            15.3041                      0.0                    6.5545
# 4            27.7033                      0.0                    3.2153
# ..               ...                      ...                       ...
# 165          16.3261                      0.0                    2.5449
# 166          33.2484                      0.0                    3.7155
# 167          12.5401                      0.0                   11.5271
# 168           9.6005                      0.0                   14.3225
# 169          10.3796                      0.0                    9.7922
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Pulses  \
# 0    0.6859         0.0327                   0.4246   6.1244  ...  0.1960
# 1    1.6448         0.1445                   0.6418   8.7428  ...  0.1148
# 2    1.2171         0.2008                   0.5772   3.8961  ...  0.2698
# 3    0.1539         1.4155                   0.3488  11.0268  ...  0.3282
# 4    0.3872         1.5263                   1.2177  14.3202  ...  0.0673
# ..      ...            ...                      ...      ...  ...     ...
# 165  0.6555         0.5707                   0.9640   7.0949  ...  0.1157
# 166  0.7839         1.1217                   0.4079  26.4292  ...  0.0765
# 167  0.5514         0.3847                   0.2564   8.0010  ...  0.5001
# 168  0.6266         1.0070                   0.1343   4.9010  ...  0.0783
# 169  0.3682         0.2455                   0.0614   4.5674  ...  0.1140
#
#      Spices  Starchy Roots  Stimulants  Sugar & Sweeteners  Sugar Crops  \
# 0    0.2776         0.0490      0.0980                 0.0       0.0000
# 1    0.0000         0.0510      0.5270                 0.0       0.0000
# 2    0.1568         0.1129      0.2886                 0.0       0.0000
# 3    0.0103         0.7078      0.1128                 0.0       0.0000
# 4    0.3591         0.0449      1.0549                 0.0       0.0000
# ..      ...            ...         ...                 ...          ...
# 165  0.0000         0.1311      0.0848                 0.0       0.0000
# 166  0.6309         0.0701      0.0829                 0.0       0.0382
# 167  0.1026         0.0513      0.3718                 0.0       0.0000
# 168  0.1567         0.2014      0.0671                 0.0       0.0000
# 169  0.0526         0.0877      0.1052                 0.0       0.0000
#
#      Treenuts  Vegetable Oils  Vegetables  Vegetal Products
# 0      0.7513         17.0831      0.3593           28.3684
# 1      0.9181          9.2443      0.6503           17.9998
# 2      0.8595         27.3606      0.5145           35.5857
# 3      0.0308         22.4638      0.1231           34.7010
# 4      0.2020         14.4436      0.2469           22.2995
# ..        ...             ...         ...               ...
# 165    0.0154         29.5211      0.1851           33.6855
# 166    1.1726          5.6211      0.6373           16.7548
# 167    0.0769         23.6312      0.1667           37.4535
# 168    0.0112         15.2848      0.1567           40.3939
# 169    0.4296         26.9396      0.0789           39.6248
#
# [170 rows x 24 columns]

# %%
df_fat_new.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal fats', 'Animal Products',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops',
#        'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners',
#        'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables',
#        'Vegetal Products'],
#       dtype='object')

# %%
# Selanjutnya gabungkan dataset pada hint di atas dengan menambahkan suffix berbeda untuk setiap supply dataset menggunakan pd.merge
# Code here
df = pd.merge(pd.merge(pd.merge(df_food_new,df_protein_new,on='Country', suffixes=['_food','_protein']),df_fat_new,on='Country',suffixes=[None,'_fat']), df_non_supply_new,on='Country')

df
# Out:
#                                 Country  Alcoholic Beverages_food  \
# 0                           Afghanistan                    0.0014
# 1                               Albania                    1.6719
# 2                               Algeria                    0.2711
# 3                                Angola                    5.8087
# 4                   Antigua and Barbuda                    3.5764
# ..                                  ...                       ...
# 165  Venezuela (Bolivarian Republic of)                    2.5952
# 166                             Vietnam                    1.4591
# 167                               Yemen                    0.0364
# 168                              Zambia                    5.7360
# 169                            Zimbabwe                    4.0552
#
#      Animal fats_food  Animal Products_food  Aquatic Products, Other_food  \
# 0              0.1973                9.4341                        0.0000
# 1              0.1357               18.7684                        0.0000
# 2              0.0282                9.6334                        0.0000
# 3              0.0560                4.9278                        0.0000
# 4              0.0087               16.6613                        0.0000
# ..                ...                   ...                           ...
# 165            0.0403               14.7565                        0.0000
# 166            0.1640                8.5765                        0.0042
# 167            0.0446                5.7874                        0.0000
# 168            0.0829                6.0197                        0.0000
# 169            0.0755                8.1489                        0.0000
#
#      Cereals - Excluding Beer_food  Eggs_food  Fish, Seafood_food  \
# 0                          24.8097     0.2099              0.0350
# 1                           5.7817     0.5815              0.2126
# 2                          13.6816     0.5277              0.2416
# 3                           9.1085     0.0587              1.7707
# 4                           5.9960     0.2274              4.1489
# ..                             ...        ...                 ...
# 165                        12.9253     0.3389              0.9456
# 166                        16.8740     0.3077              2.6392
# 167                        27.2077     0.2579              0.5240
# 168                        21.1938     0.3399              1.6924
# 169                        22.6240     0.2678              0.5518
#
#      Fruits - Excluding Wine_food  Meat_food  ...  Vegetables  \
# 0                          5.3495     1.2020  ...      0.3593
# 1                          6.7861     1.8845  ...      0.6503
# 2                          6.3801     1.1305  ...      0.5145
# 3                          6.0005     2.0571  ...      0.1231
# 4                         10.7451     5.6888  ...      0.2469
# ..                            ...        ...  ...         ...
# 165                        7.6460     3.8328  ...      0.1851
# 166                        5.9029     4.4382  ...      0.6373
# 167                        5.1344     2.7871  ...      0.1667
# 168                        1.0183     1.8427  ...      0.1567
# 169                        2.2000     2.6142  ...      0.0789
#
#      Vegetal Products  Obesity  Undernourished  Confirmed    Deaths  \
# 0             28.3684      4.5            29.8   0.130125  0.005461
# 1             17.9998     22.3             6.2   1.931889  0.039641
# 2             35.5857     26.6             3.9   0.218696  0.006098
# 3             34.7010      6.8              25   0.052361  0.001208
# 4             22.2995     19.1             NaN   0.157143  0.005102
# ..                ...      ...             ...        ...       ...
# 165           33.6855     25.2            21.2   0.388357  0.003512
# 166           16.7548      2.1             9.3   0.001488  0.000036
# 167           37.4535     14.1            38.9   0.007014  0.002032
# 168           40.3939      6.5            46.7   0.104624  0.002072
# 169           39.6248     12.3            51.3   0.086026  0.002281
#
#      Recovered    Active  Population  Unit (all except Population)
# 0     0.103676  0.020987  38928000.0                             %
# 1     1.066808  0.825440   2838000.0                             %
# 2     0.146036  0.066562  44357000.0                             %
# 3     0.029915  0.021238  32522000.0                             %
# 4     0.148980  0.003061     98000.0                             %
# ..         ...       ...         ...                           ...
# 165   0.368228  0.016617  28645000.0                             %
# 166   0.001331  0.000121  96209000.0                             %
# 167   0.004640  0.000342  29826000.0                             %
# 168   0.098107  0.004444  18384000.0                             %
# 169   0.069394  0.014351  14863000.0                             %
#
# [170 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Alcoholic Beverages_food', 'Animal fats_food',
#        'Animal Products_food', 'Aquatic Products, Other_food',
#        'Cereals - Excluding Beer_food', 'Eggs_food', 'Fish, Seafood_food',
#        'Fruits - Excluding Wine_food', 'Meat_food',
#        'Milk - Excluding Butter_food', 'Miscellaneous_food', 'Offals_food',
#        'Oilcrops_food', 'Pulses_food', 'Spices_food', 'Starchy Roots_food',
#        'Stimulants_food', 'Sugar & Sweeteners_food', 'Sugar Crops_food',
#        'Treenuts_food', 'Vegetable Oils_food', 'Vegetables_food',
#        'Vegetal Products_food', 'Alcoholic Beverages_protein',
#        'Animal fats_protein', 'Animal Products_protein',
#        'Aquatic Products, Other_protein', 'Cereals - Excluding Beer_protein',
#        'Eggs_protein', 'Fish, Seafood_protein',
#        'Fruits - Excluding Wine_protein', 'Meat_protein',
#        'Milk - Excluding Butter_protein', 'Miscellaneous_protein',
#        'Offals_protein', 'Oilcrops_protein', 'Pulses_protein',
#        'Spices_protein', 'Starchy Roots_protein', 'Stimulants_protein',
#        'Sugar & Sweeteners_protein', 'Sugar Crops_protein', 'Treenuts_protein',
#        'Vegetable Oils_protein', 'Vegetables_protein',
#        'Vegetal Products_protein', 'Alcoholic Beverages', 'Animal fats',
#        'Animal Products', 'Aquatic Products, Other',
#        'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood',
#        'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter',
#        'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops',
#        'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products',
#        'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %% [markdown]
# Expected output (kolom tidak semua ditampilkan):
#
# ![Expected Output:](https://drive.google.com/uc?id=1W9dSQu4SVlWV2SkW4ZNYnwF60tDWMGEx)

# %% [markdown]
# ---

# %% [markdown]
# # Soal 4: Sorting dan Filtering

# %% [markdown]
# Dari DataFrame hasil penggabungan pada Soal 2 (atau gunakan salah satu supply DataFrame karena kolom nilai non-supply memiliki nilai yang sama), kemudian urutkan data (sort) berdasarkan kolom kematian ('Deaths') dari yang terbesar. Setelah itu lakukan perintah berikut:
#
# - Print data hasil sorting
# - Urutan ke berapakah Indonesia berdasarkan tingkat kematian akibat COVID-19 setelah diurutkan dari yang terbesar? Gunakan code mendapatkan nilainya!
# - Berapa persen dari populasi jumlah kematian akibat COVID-19 di Indonesia? Hitung jumlah orang yang meninggal! Gunakan code mendapatkan nilainya! #hint: jumlah orang yang meninggal = populasi * kematian --> jangan lupa ada yang masih dalam persen

# %%
# Urutkan (sorting) dan print hasil sorting
# Code here
df.sort_values(by=['Deaths'])
df
# Out:
#                                 Country  Alcoholic Beverages_food  \
# 0                           Afghanistan                    0.0014
# 1                               Albania                    1.6719
# 2                               Algeria                    0.2711
# 3                                Angola                    5.8087
# 4                   Antigua and Barbuda                    3.5764
# ..                                  ...                       ...
# 165  Venezuela (Bolivarian Republic of)                    2.5952
# 166                             Vietnam                    1.4591
# 167                               Yemen                    0.0364
# 168                              Zambia                    5.7360
# 169                            Zimbabwe                    4.0552
#
#      Animal fats_food  Animal Products_food  Aquatic Products, Other_food  \
# 0              0.1973                9.4341                        0.0000
# 1              0.1357               18.7684                        0.0000
# 2              0.0282                9.6334                        0.0000
# 3              0.0560                4.9278                        0.0000
# 4              0.0087               16.6613                        0.0000
# ..                ...                   ...                           ...
# 165            0.0403               14.7565                        0.0000
# 166            0.1640                8.5765                        0.0042
# 167            0.0446                5.7874                        0.0000
# 168            0.0829                6.0197                        0.0000
# 169            0.0755                8.1489                        0.0000
#
#      Cereals - Excluding Beer_food  Eggs_food  Fish, Seafood_food  \
# 0                          24.8097     0.2099              0.0350
# 1                           5.7817     0.5815              0.2126
# 2                          13.6816     0.5277              0.2416
# 3                           9.1085     0.0587              1.7707
# 4                           5.9960     0.2274              4.1489
# ..                             ...        ...                 ...
# 165                        12.9253     0.3389              0.9456
# 166                        16.8740     0.3077              2.6392
# 167                        27.2077     0.2579              0.5240
# 168                        21.1938     0.3399              1.6924
# 169                        22.6240     0.2678              0.5518
#
#      Fruits - Excluding Wine_food  Meat_food  ...  Vegetables  \
# 0                          5.3495     1.2020  ...      0.3593
# 1                          6.7861     1.8845  ...      0.6503
# 2                          6.3801     1.1305  ...      0.5145
# 3                          6.0005     2.0571  ...      0.1231
# 4                         10.7451     5.6888  ...      0.2469
# ..                            ...        ...  ...         ...
# 165                        7.6460     3.8328  ...      0.1851
# 166                        5.9029     4.4382  ...      0.6373
# 167                        5.1344     2.7871  ...      0.1667
# 168                        1.0183     1.8427  ...      0.1567
# 169                        2.2000     2.6142  ...      0.0789
#
#      Vegetal Products  Obesity  Undernourished  Confirmed    Deaths  \
# 0             28.3684      4.5            29.8   0.130125  0.005461
# 1             17.9998     22.3             6.2   1.931889  0.039641
# 2             35.5857     26.6             3.9   0.218696  0.006098
# 3             34.7010      6.8              25   0.052361  0.001208
# 4             22.2995     19.1             NaN   0.157143  0.005102
# ..                ...      ...             ...        ...       ...
# 165           33.6855     25.2            21.2   0.388357  0.003512
# 166           16.7548      2.1             9.3   0.001488  0.000036
# 167           37.4535     14.1            38.9   0.007014  0.002032
# 168           40.3939      6.5            46.7   0.104624  0.002072
# 169           39.6248     12.3            51.3   0.086026  0.002281
#
#      Recovered    Active  Population  Unit (all except Population)
# 0     0.103676  0.020987  38928000.0                             %
# 1     1.066808  0.825440   2838000.0                             %
# 2     0.146036  0.066562  44357000.0                             %
# 3     0.029915  0.021238  32522000.0                             %
# 4     0.148980  0.003061     98000.0                             %
# ..         ...       ...         ...                           ...
# 165   0.368228  0.016617  28645000.0                             %
# 166   0.001331  0.000121  96209000.0                             %
# 167   0.004640  0.000342  29826000.0                             %
# 168   0.098107  0.004444  18384000.0                             %
# 169   0.069394  0.014351  14863000.0                             %
#
# [170 rows x 78 columns]

# %%
# Urutan ke berapakah Indonesia
# Code here
# df['Country']='Indonesia'
a = df['Country'].tolist()
a.index('Indonesia')
# Out:
# 69

# %%
# Berapa persen jumlah kematian di Indonesia? Berapa Jumlahnya?
# Code here
popul = df.iloc[5]['Population']
meninggal_persen = df.iloc[69]['Deaths']
meninggal = meninggal_persen*popul

print(f'Jumlah yang meninggal di Indonesia ada {round(meninggal_persen, 10)}% dari jumlah populasi.') # 10 digit
print(f'Jumlah yang meninggal di Indonesia ada {round(meninggal)} orang.')
# Out:
# Jumlah yang meninggal di Indonesia ada 0.0075767556% dari jumlah populasi.
# Jumlah yang meninggal di Indonesia ada 343810 orang.

# %% [markdown]
# \n

# %% [markdown]
# # Soal 5: Binning, Grouping, dan Aggregating data

# %% [markdown]
# Lakukan binning pada kolom terkonfirmasi (Confirmed) COVID-19 dari DataFrame df_fat menjadi 5 bagian (q=5). Teman-teman dapat menggunakan fungsi qcut untuk melakukan bininng ini. Masukan data hasil binning tersebut menjadi kolom baru pada DataFrame df_fat. Beri nama kolom tersebut dengan 'Confirmed Category'. Berikan label 'Sangat Tidak Banyak', 'Tidak Banyak', 'Sedang', 'Cukup Banyak', 'Sangat Banyak'.
#
# Baca dokumentasi berikut untuk fungsi qcut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html
#
# Kemudian lakukan perintah-perintah berikut:
# - Buat DataFrame baru yang berisi data grouping berdasarkan kolom hasil bininng atau kolom 'Confirmed Category'.
# - Lakukan grouping hanya pada kolom 'Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products', 'Vegetal Products' saja.
# - Kemudian aggregate dengan fungsi mean. (df_baru = df_fat.groupby(...).mean())
# - Save DataFrame hasil binning, grouping, dan aggregating ke dalam file csv.

# %%
# Lakukan binning pada kolom terkonfirmasi untuk DataFrame df_fat
labels = ['Sangat Tidak Banyak', 'Tidak Banyak', 'Sedang', 'Cukup Banyak', 'Sangat Banyak']

# Code here
df_fat['Confirmed Category'] = pd.qcut(range(170), 5, labels=labels)

# %%
# Lakukan grouping pada kolom hasil binning ('Confirmed Category'), kemudian aggregate menggunakan fungsi mean
cols = ['Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products', 'Vegetal Products']

# Code here
groupbaru = df_fat.groupby('Confirmed Category').mean()
groupby_confirmed = groupbaru[cols]
groupby_confirmed
# Out:
#                        Obesity       Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  17.908824  10.381412                 0.451000
# Tidak Banyak         20.224242   9.006382                 0.698271
# Sedang               18.150000   9.028753                 0.450003
# Cukup Banyak         19.066667  10.004856                 0.717132
# Sangat Banyak        18.230303   9.049994                 0.394179
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       0.793574        22.266418         27.734109
# Tidak Banyak              0.799503        20.819212         29.181138
# Sedang                    1.119824        19.926547         30.074003
# Cukup Banyak              0.832938        21.823426         28.176132
# Sangat Banyak             0.706347        18.642968         31.356600

# %% [markdown]
# Expected output:
#
# ![Expected Output:](https://drive.google.com/uc?id=1j3bfG4anCm2wkABRG-gaLmTIQyXTSqkA)

# %%
# Save DataFrame hasil binning, grouping, dan aggregating

groupby_confirmed.to_csv('groupby_confirmed.csv')

# %% [markdown]
# ---

# %% [markdown]
# # Soal 6: Bar plot

# %% [markdown]
# Gunakan data grouping pada soal sebelumnya untuk melakukan visualisasi. Jika kalian tidak dapat menyelesaikan soal tersebut, maka silahkan [download](https://drive.google.com/uc?export=download&id=1PW_Q9dHRzexm6KgIfTcc0iSCDm47t-Hb) data berikut yang merupakan hasil dari data grouping soal 4.
#
# Normalisasi data hasil grouping tersebut dengan rumus min-max normalisasi seperti rumus berikut ini. Kemudian buatlah grouping Visualization dengan berplot, visualisasikan data column 'Obesity', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products' dan 'Vegetal Products'.

# %% [markdown]
# \begin{equation*}
#  X_{norm} = \dfrac{X - X_{min}}{X_{max} - X_{min}}
# \end{equation*}

# %%
# Gunakan DataFrame hasil grouping soal 4 atau read data hasil download jika tidak dapat mengerjakan soal 4
# df = groupby_confirmed

# Atau

df = pd.read_csv('groupby_confirmed.csv').set_index('Confirmed Category')

# Lihat df dan pastikan sesuai dengan expected output pada soal 4
display(df)
# Out:
#                        Obesity       Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  17.908824  10.381412                 0.451000
# Tidak Banyak         20.224242   9.006382                 0.698271
# Sedang               18.150000   9.028753                 0.450003
# Cukup Banyak         19.066667  10.004856                 0.717132
# Sangat Banyak        18.230303   9.049994                 0.394179
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       0.793574        22.266418         27.734109
# Tidak Banyak              0.799503        20.819212         29.181138
# Sedang                    1.119824        19.926547         30.074003
# Cukup Banyak              0.832938        21.823426         28.176132
# Sangat Banyak             0.706347        18.642968         31.356600

# %%
x = df.values
xnorm = (x-x.min())/(x.max()-x.min())

# %%
print(xnorm)
# Out:
# [[0.56567425 0.32255981 0.00183515 0.01289932 0.70641241 0.88300362]
#  [0.64045584 0.27815018 0.0098213  0.01309082 0.65967169 0.92973864]
#  [0.57346358 0.27887269 0.00180294 0.02343629 0.63084111 0.95857569]
#  [0.60306936 0.3103981  0.01043048 0.01417069 0.69210503 0.89727975]
#  [0.57605715 0.27955872 0.         0.01008215 0.58938506 1.        ]]

# %%
# Find the name of the column by index
n = df.columns

# Drop that column
df.drop(n, axis = 1, inplace = True)

# Put whatever series you want in its place
df[n] = xnorm

# %%
# Lakukan normalisasi pada DataFrame df
# Code here

n = df.columns
df.drop(n, axis = 1, inplace = True)
df[n] = xnorm

# Lihat df_norm dan pastikan sesuai dengan expected output
display(df)
# Out:
#                       Obesity      Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak  0.565674  0.322560                 0.001835
# Tidak Banyak         0.640456  0.278150                 0.009821
# Sedang               0.573464  0.278873                 0.001803
# Cukup Banyak         0.603069  0.310398                 0.010430
# Sangat Banyak        0.576057  0.279559                 0.000000
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       0.012899         0.706412          0.883004
# Tidak Banyak              0.013091         0.659672          0.929739
# Sedang                    0.023436         0.630841          0.958576
# Cukup Banyak              0.014171         0.692105          0.897280
# Sangat Banyak             0.010082         0.589385          1.000000

# %% [markdown]
# Expected output:
#
# ![Expected Output:](https://drive.google.com/uc?id=1FBTQUz9KgsR6TUuybwzHNz0BO-O5zA3Z)

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
fig,ax = plt.subplots(figsize=(20,10))
x = np.arange(0,5)
width = 0.1

plt.style.use('ggplot')
y = df['Obesity']
y1 = df['Meat']
y2 = df['Fruits - Excluding Wine']
y3 = df['Fish, Seafood']
y4 = df['Animal Products']
y5 = df['Vegetal Products']

ax.bar(x, y, width, label = 'Sangat Tidak Banyak')
ax.bar(x+0.3, y1, width, label = 'Tidak Banyak')
ax.bar(x+0.6, y2, width, label = 'Sedang')
ax.bar(x+0.9, y3, width, label = 'Cukup Banyak')
ax.bar(x+1.2, y4, width, label = 'Sangat Banyak')
# ax.bar(x+1.5, y5, width, label = 'Vegetal Products')

ax.set_xticks(x)
ax.set_xticklabels(df.columns)
ax.set_title('Perbandingan Konsumsi Makanan Berdasarkan Tingkat Kasus COVID-19')
ax.legend(bbox_to_anchor=(1.1, 1.1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-3e32787a7457> in <module>
#      19
#      20 ax.set_xticks(x)
# ---> 21 ax.set_xticklabels(df.columns)
#      22 ax.set_title('Perbandingan Konsumsi Makanan Berdasarkan Tingkat Kasus COVID-19')
#      23 ax.legend(bbox_to_anchor=(1.1, 1.1))
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1791         if fontdict is not None:
#    1792             kwargs.update(fontdict)
# -> 1793         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1794
#    1795     @cbook._make_keyword_only("3.2", "minor")
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1712             # remove all tick labels, so only error for > 0 ticklabels
#    1713             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1714                 raise ValueError(
#    1715                     "The number of FixedLocator locations"
#    1716                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (5), usually from a call to set_ticks, does not match the number of ticklabels (6).

# %% [markdown]
# Expected output:
#
# ![Expected Output:](https://drive.google.com/uc?id=17rsStEeNhfdHhTF8SNvBLsPiS4hoN6H2)

# %% [markdown]
# ---

# %% [markdown]
# # Soal 7: Seaborn Scatter plot

# %% [markdown]
# Buatlah visualisasi scatter plot (perpaduan seaborn dan matplotlib) dari df_food antara Supply Sayuran ('Vegetal Products') dan persentase terkonfirmasi ('Confirmed') COVID-19 sesuai expected output dengan ketentuan berikut:
#
#
# * Gunakan kolom persentase kematian ('Death') sebagai ukuran pointnya kalikan suatu angka yang cukup besar agar terlihat.
#
# * Gunakan kolom persentase produk hewani ('Animal Products') sebagai warna point, berikan cmap 'plasma'.
#
# * Untuk seaborn gunakan regplot dengan argumen scatter=False

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(18, 12))

# Code here
mapax = ax.scatter(df_food['Vegetal Products'], df_food['Confirmed'], c = df_food['Animal Products'], s=df_food['Deaths']*1e5, cmap='plasma')
ax.set_xlabel('Supply Sayuran')
ax.set_ylabel('Persentase Terkonfirmasi')
ax.set_title('Perbandingan Konsumsi Makanan Berdasarkan Tingkat Kasus COVID-19')
fig.colorbar(mapax)
sns.regplot(x = df_food['Vegetal Products'], y = df_food['Confirmed'], scatter=False)
plt.show()

# %% [markdown]
# Expected output:
#
# ![Expected Output:](https://drive.google.com/uc?id=1-6sPbxr2oWLI2Oyd0CRnd60YETjBgX5G)
